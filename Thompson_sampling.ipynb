# %% [markdown]
# <a href="https://colab.research.google.com/github/veerkalburgi/AI_projects/blob/master/Thompson_sampling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Models comparison

import numpy as np
import pandas as pd

N = [200, 1000, 5000]  # no.of samples
D = 20 # 20 samples of mechines 
convRanges = [(0., 0.1), (0., 0.3), (0., 0.5)] #Conversion rate for given three samples

results = list()
for n in N:
    for ranges in convRanges:
        results.append([])
        for d  in range(3, D + 1):
            p1 = 0
            p2 = 0

            for rounds in range(1000):
                
                conversionRates = list()
                for i in range(d):
                    conversionRates.append(np.random.uniform(low = ranges[0], high = ranges[1]))
                    
                X = np.zeros((n,d))
                for i in range(n):
                    for j in range(d):
                        if np.random.rand() < conversionRates[j]:
                            X[i][j] = 1
                
                nPosReward = np.zeros(d)
                nNegReward = np.zeros(d)
                
                for i in range(n):
                    selected = 0
                    maxRandom = 0
                    
                    for j in range(d):
                        randomBeta = np.random.beta(nPosReward[j] + 1, nNegReward[j] + 1) #Beta distribution  Function.
                        if randomBeta > maxRandom:
                            maxRandom = randomBeta
                            selected = j
                        
                    if X[i][selected] == 1:
                        nPosReward[selected] += 1
                    else:
                        nNegReward[selected] += 1
                
                nSelected = nPosReward + nNegReward
                
                left = n - max(nSelected)
                
                countStandard = np.zeros(d)
                
                x = int(left / d)
                for i in range(x):
                    for j in range(d):
                        if X[i][j] == 1:
                            countStandard[j] += 1
                
                bestStandard = np.argmax(countStandard)
                bestReal = np.argmax(conversionRates)
                bestTS = np.argmax(nSelected)

                if bestTS == bestReal:
                    p1 += 1
                if bestStandard == bestReal:
                    p2 += 1
                
            print('N = ' + str(n) + ' d = ' + str(d) + ' range = ' + str(ranges) + ' | result Thompson Sampling = ' + str(p1) + ' result Standard solution = ' + str(p2))
            results.append([n, ranges, d, p1, p2])
                
df = pd.DataFrame(results)
df.to_excel('results.xlsx', sheet_name = 'Result', index = False)
# Out:
# N = 200 d = 3 range = (0.0, 0.1) | result Thompson Sampling = 633 result Standard solution = 572
# N = 200 d = 4 range = (0.0, 0.1) | result Thompson Sampling = 565 result Standard solution = 499
# N = 200 d = 5 range = (0.0, 0.1) | result Thompson Sampling = 486 result Standard solution = 410
# N = 200 d = 6 range = (0.0, 0.1) | result Thompson Sampling = 407 result Standard solution = 369
# N = 200 d = 7 range = (0.0, 0.1) | result Thompson Sampling = 365 result Standard solution = 327
# N = 200 d = 8 range = (0.0, 0.1) | result Thompson Sampling = 346 result Standard solution = 280
# N = 200 d = 9 range = (0.0, 0.1) | result Thompson Sampling = 301 result Standard solution = 261
# N = 200 d = 10 range = (0.0, 0.1) | result Thompson Sampling = 281 result Standard solution = 250
# N = 200 d = 11 range = (0.0, 0.1) | result Thompson Sampling = 255 result Standard solution = 226
# N = 200 d = 12 range = (0.0, 0.1) | result Thompson Sampling = 226 result Standard solution = 206
# N = 200 d = 13 range = (0.0, 0.1) | result Thompson Sampling = 200 result Standard solution = 214
# N = 200 d = 14 range = (0.0, 0.1) | result Thompson Sampling = 213 result Standard solution = 172
# N = 200 d = 15 range = (0.0, 0.1) | result Thompson Sampling = 177 result Standard solution = 156
# N = 200 d = 16 range = (0.0, 0.1) | result Thompson Sampling = 166 result Standard solution = 154
# N = 200 d = 17 range = (0.0, 0.1) | result Thompson Sampling = 174 result Standard solution = 142
# N = 200 d = 18 range = (0.0, 0.1) | result Thompson Sampling = 164 result Standard solution = 140
# N = 200 d = 19 range = (0.0, 0.1) | result Thompson Sampling = 143 result Standard solution = 125
# N = 200 d = 20 range = (0.0, 0.1) | result Thompson Sampling = 131 result Standard solution = 150
# N = 200 d = 3 range = (0.0, 0.3) | result Thompson Sampling = 776 result Standard solution = 649
# N = 200 d = 4 range = (0.0, 0.3) | result Thompson Sampling = 684 result Standard solution = 610
# N = 200 d = 5 range = (0.0, 0.3) | result Thompson Sampling = 636 result Standard solution = 518
# N = 200 d = 6 range = (0.0, 0.3) | result Thompson Sampling = 560 result Standard solution = 470
# N = 200 d = 7 range = (0.0, 0.3) | result Thompson Sampling = 509 result Standard solution = 435
# N = 200 d = 8 range = (0.0, 0.3) | result Thompson Sampling = 475 result Standard solution = 381
# N = 200 d = 9 range = (0.0, 0.3) | result Thompson Sampling = 429 result Standard solution = 338
# N = 200 d = 10 range = (0.0, 0.3) | result Thompson Sampling = 406 result Standard solution = 345
# N = 200 d = 11 range = (0.0, 0.3) | result Thompson Sampling = 382 result Standard solution = 294
# N = 200 d = 12 range = (0.0, 0.3) | result Thompson Sampling = 323 result Standard solution = 278
# N = 200 d = 13 range = (0.0, 0.3) | result Thompson Sampling = 316 result Standard solution = 302
# N = 200 d = 14 range = (0.0, 0.3) | result Thompson Sampling = 293 result Standard solution = 262
# N = 200 d = 15 range = (0.0, 0.3) | result Thompson Sampling = 271 result Standard solution = 232
# N = 200 d = 16 range = (0.0, 0.3) | result Thompson Sampling = 263 result Standard solution = 234
# N = 200 d = 17 range = (0.0, 0.3) | result Thompson Sampling = 241 result Standard solution = 209
# N = 200 d = 18 range = (0.0, 0.3) | result Thompson Sampling = 235 result Standard solution = 174
# N = 200 d = 19 range = (0.0, 0.3) | result Thompson Sampling = 228 result Standard solution = 161
# N = 200 d = 20 range = (0.0, 0.3) | result Thompson Sampling = 230 result Standard solution = 174
# N = 200 d = 3 range = (0.0, 0.5) | result Thompson Sampling = 831 result Standard solution = 703
# N = 200 d = 4 range = (0.0, 0.5) | result Thompson Sampling = 780 result Standard solution = 649
# N = 200 d = 5 range = (0.0, 0.5) | result Thompson Sampling = 710 result Standard solution = 592
# N = 200 d = 6 range = (0.0, 0.5) | result Thompson Sampling = 620 result Standard solution = 530
# N = 200 d = 7 range = (0.0, 0.5) | result Thompson Sampling = 608 result Standard solution = 473
# N = 200 d = 8 range = (0.0, 0.5) | result Thompson Sampling = 543 result Standard solution = 441
# N = 200 d = 9 range = (0.0, 0.5) | result Thompson Sampling = 527 result Standard solution = 402
# N = 200 d = 10 range = (0.0, 0.5) | result Thompson Sampling = 468 result Standard solution = 347
# N = 200 d = 11 range = (0.0, 0.5) | result Thompson Sampling = 458 result Standard solution = 340
# N = 200 d = 12 range = (0.0, 0.5) | result Thompson Sampling = 428 result Standard solution = 310
# N = 200 d = 13 range = (0.0, 0.5) | result Thompson Sampling = 415 result Standard solution = 324
# N = 200 d = 14 range = (0.0, 0.5) | result Thompson Sampling = 378 result Standard solution = 267
# N = 200 d = 15 range = (0.0, 0.5) | result Thompson Sampling = 385 result Standard solution = 281
# N = 200 d = 16 range = (0.0, 0.5) | result Thompson Sampling = 314 result Standard solution = 253
# N = 200 d = 17 range = (0.0, 0.5) | result Thompson Sampling = 297 result Standard solution = 266
# N = 200 d = 18 range = (0.0, 0.5) | result Thompson Sampling = 342 result Standard solution = 211
# N = 200 d = 19 range = (0.0, 0.5) | result Thompson Sampling = 301 result Standard solution = 236
# N = 200 d = 20 range = (0.0, 0.5) | result Thompson Sampling = 301 result Standard solution = 200
# N = 1000 d = 3 range = (0.0, 0.1) | result Thompson Sampling = 794 result Standard solution = 677
# N = 1000 d = 4 range = (0.0, 0.1) | result Thompson Sampling = 739 result Standard solution = 622
# N = 1000 d = 5 range = (0.0, 0.1) | result Thompson Sampling = 680 result Standard solution = 561
# N = 1000 d = 6 range = (0.0, 0.1) | result Thompson Sampling = 619 result Standard solution = 488
# N = 1000 d = 7 range = (0.0, 0.1) | result Thompson Sampling = 544 result Standard solution = 481
# N = 1000 d = 8 range = (0.0, 0.1) | result Thompson Sampling = 527 result Standard solution = 415
# N = 1000 d = 9 range = (0.0, 0.1) | result Thompson Sampling = 471 result Standard solution = 397
# N = 1000 d = 10 range = (0.0, 0.1) | result Thompson Sampling = 450 result Standard solution = 374
# N = 1000 d = 11 range = (0.0, 0.1) | result Thompson Sampling = 397 result Standard solution = 357
# N = 1000 d = 12 range = (0.0, 0.1) | result Thompson Sampling = 372 result Standard solution = 285
# N = 1000 d = 13 range = (0.0, 0.1) | result Thompson Sampling = 381 result Standard solution = 312
# N = 1000 d = 14 range = (0.0, 0.1) | result Thompson Sampling = 311 result Standard solution = 273
# N = 1000 d = 15 range = (0.0, 0.1) | result Thompson Sampling = 304 result Standard solution = 255
# N = 1000 d = 16 range = (0.0, 0.1) | result Thompson Sampling = 308 result Standard solution = 250
# N = 1000 d = 17 range = (0.0, 0.1) | result Thompson Sampling = 292 result Standard solution = 207
# N = 1000 d = 18 range = (0.0, 0.1) | result Thompson Sampling = 288 result Standard solution = 240
# N = 1000 d = 19 range = (0.0, 0.1) | result Thompson Sampling = 253 result Standard solution = 203
# N = 1000 d = 20 range = (0.0, 0.1) | result Thompson Sampling = 240 result Standard solution = 188
# N = 1000 d = 3 range = (0.0, 0.3) | result Thompson Sampling = 867 result Standard solution = 743
# N = 1000 d = 4 range = (0.0, 0.3) | result Thompson Sampling = 811 result Standard solution = 707
# N = 1000 d = 5 range = (0.0, 0.3) | result Thompson Sampling = 816 result Standard solution = 616
# N = 1000 d = 6 range = (0.0, 0.3) | result Thompson Sampling = 730 result Standard solution = 584
# N = 1000 d = 7 range = (0.0, 0.3) | result Thompson Sampling = 696 result Standard solution = 558
# N = 1000 d = 8 range = (0.0, 0.3) | result Thompson Sampling = 676 result Standard solution = 539
# N = 1000 d = 9 range = (0.0, 0.3) | result Thompson Sampling = 638 result Standard solution = 493
# N = 1000 d = 10 range = (0.0, 0.3) | result Thompson Sampling = 612 result Standard solution = 447
# N = 1000 d = 11 range = (0.0, 0.3) | result Thompson Sampling = 561 result Standard solution = 455
# N = 1000 d = 12 range = (0.0, 0.3) | result Thompson Sampling = 553 result Standard solution = 403
# N = 1000 d = 13 range = (0.0, 0.3) | result Thompson Sampling = 530 result Standard solution = 410
# N = 1000 d = 14 range = (0.0, 0.3) | result Thompson Sampling = 520 result Standard solution = 384
# N = 1000 d = 15 range = (0.0, 0.3) | result Thompson Sampling = 478 result Standard solution = 333
# N = 1000 d = 16 range = (0.0, 0.3) | result Thompson Sampling = 459 result Standard solution = 347
# N = 1000 d = 17 range = (0.0, 0.3) | result Thompson Sampling = 434 result Standard solution = 331
# N = 1000 d = 18 range = (0.0, 0.3) | result Thompson Sampling = 413 result Standard solution = 297
# N = 1000 d = 19 range = (0.0, 0.3) | result Thompson Sampling = 406 result Standard solution = 296
# N = 1000 d = 20 range = (0.0, 0.3) | result Thompson Sampling = 397 result Standard solution = 254
# N = 1000 d = 3 range = (0.0, 0.5) | result Thompson Sampling = 903 result Standard solution = 787
# N = 1000 d = 4 range = (0.0, 0.5) | result Thompson Sampling = 877 result Standard solution = 734
# N = 1000 d = 5 range = (0.0, 0.5) | result Thompson Sampling = 846 result Standard solution = 687
# N = 1000 d = 6 range = (0.0, 0.5) | result Thompson Sampling = 816 result Standard solution = 610
# N = 1000 d = 7 range = (0.0, 0.5) | result Thompson Sampling = 763 result Standard solution = 600
# N = 1000 d = 8 range = (0.0, 0.5) | result Thompson Sampling = 764 result Standard solution = 558
# N = 1000 d = 9 range = (0.0, 0.5) | result Thompson Sampling = 723 result Standard solution = 533
# N = 1000 d = 10 range = (0.0, 0.5) | result Thompson Sampling = 707 result Standard solution = 475
# N = 1000 d = 11 range = (0.0, 0.5) | result Thompson Sampling = 697 result Standard solution = 491
# N = 1000 d = 12 range = (0.0, 0.5) | result Thompson Sampling = 656 result Standard solution = 462
# N = 1000 d = 13 range = (0.0, 0.5) | result Thompson Sampling = 635 result Standard solution = 459
# N = 1000 d = 14 range = (0.0, 0.5) | result Thompson Sampling = 604 result Standard solution = 400
# N = 1000 d = 15 range = (0.0, 0.5) | result Thompson Sampling = 583 result Standard solution = 418
# N = 1000 d = 16 range = (0.0, 0.5) | result Thompson Sampling = 561 result Standard solution = 379
# N = 1000 d = 17 range = (0.0, 0.5) | result Thompson Sampling = 574 result Standard solution = 395
# N = 1000 d = 18 range = (0.0, 0.5) | result Thompson Sampling = 519 result Standard solution = 349
# N = 1000 d = 19 range = (0.0, 0.5) | result Thompson Sampling = 554 result Standard solution = 383
# N = 1000 d = 20 range = (0.0, 0.5) | result Thompson Sampling = 501 result Standard solution = 322
# N = 5000 d = 3 range = (0.0, 0.1) | result Thompson Sampling = 894 result Standard solution = 771
# N = 5000 d = 4 range = (0.0, 0.1) | result Thompson Sampling = 870 result Standard solution = 726
# N = 5000 d = 5 range = (0.0, 0.1) | result Thompson Sampling = 811 result Standard solution = 680
# N = 5000 d = 6 range = (0.0, 0.1) | result Thompson Sampling = 788 result Standard solution = 633
# N = 5000 d = 7 range = (0.0, 0.1) | result Thompson Sampling = 746 result Standard solution = 591
# N = 5000 d = 8 range = (0.0, 0.1) | result Thompson Sampling = 714 result Standard solution = 537
# N = 5000 d = 9 range = (0.0, 0.1) | result Thompson Sampling = 700 result Standard solution = 509
# N = 5000 d = 10 range = (0.0, 0.1) | result Thompson Sampling = 670 result Standard solution = 514
# N = 5000 d = 11 range = (0.0, 0.1) | result Thompson Sampling = 623 result Standard solution = 477
# N = 5000 d = 12 range = (0.0, 0.1) | result Thompson Sampling = 581 result Standard solution = 429
# N = 5000 d = 13 range = (0.0, 0.1) | result Thompson Sampling = 585 result Standard solution = 419
# N = 5000 d = 14 range = (0.0, 0.1) | result Thompson Sampling = 572 result Standard solution = 409
# N = 5000 d = 15 range = (0.0, 0.1) | result Thompson Sampling = 512 result Standard solution = 375
# N = 5000 d = 16 range = (0.0, 0.1) | result Thompson Sampling = 532 result Standard solution = 347
# N = 5000 d = 17 range = (0.0, 0.1) | result Thompson Sampling = 515 result Standard solution = 337
# N = 5000 d = 18 range = (0.0, 0.1) | result Thompson Sampling = 456 result Standard solution = 358
# N = 5000 d = 19 range = (0.0, 0.1) | result Thompson Sampling = 472 result Standard solution = 340
# N = 5000 d = 20 range = (0.0, 0.1) | result Thompson Sampling = 402 result Standard solution = 300
# N = 5000 d = 3 range = (0.0, 0.3) | result Thompson Sampling = 927 result Standard solution = 831
# N = 5000 d = 4 range = (0.0, 0.3) | result Thompson Sampling = 912 result Standard solution = 781
# N = 5000 d = 5 range = (0.0, 0.3) | result Thompson Sampling = 897 result Standard solution = 762
# N = 5000 d = 6 range = (0.0, 0.3) | result Thompson Sampling = 874 result Standard solution = 674
# N = 5000 d = 7 range = (0.0, 0.3) | result Thompson Sampling = 860 result Standard solution = 662
# N = 5000 d = 8 range = (0.0, 0.3) | result Thompson Sampling = 809 result Standard solution = 637
# N = 5000 d = 9 range = (0.0, 0.3) | result Thompson Sampling = 799 result Standard solution = 597
# N = 5000 d = 10 range = (0.0, 0.3) | result Thompson Sampling = 761 result Standard solution = 581
# N = 5000 d = 11 range = (0.0, 0.3) | result Thompson Sampling = 772 result Standard solution = 566
# N = 5000 d = 12 range = (0.0, 0.3) | result Thompson Sampling = 755 result Standard solution = 528
# N = 5000 d = 13 range = (0.0, 0.3) | result Thompson Sampling = 716 result Standard solution = 517
# N = 5000 d = 14 range = (0.0, 0.3) | result Thompson Sampling = 732 result Standard solution = 496
# N = 5000 d = 15 range = (0.0, 0.3) | result Thompson Sampling = 724 result Standard solution = 500
# N = 5000 d = 16 range = (0.0, 0.3) | result Thompson Sampling = 702 result Standard solution = 458
# N = 5000 d = 17 range = (0.0, 0.3) | result Thompson Sampling = 661 result Standard solution = 453
# N = 5000 d = 18 range = (0.0, 0.3) | result Thompson Sampling = 651 result Standard solution = 418
# N = 5000 d = 19 range = (0.0, 0.3) | result Thompson Sampling = 640 result Standard solution = 435
# N = 5000 d = 20 range = (0.0, 0.3) | result Thompson Sampling = 653 result Standard solution = 401
# N = 5000 d = 3 range = (0.0, 0.5) | result Thompson Sampling = 969 result Standard solution = 839
# N = 5000 d = 4 range = (0.0, 0.5) | result Thompson Sampling = 935 result Standard solution = 794
# N = 5000 d = 5 range = (0.0, 0.5) | result Thompson Sampling = 931 result Standard solution = 751
# N = 5000 d = 6 range = (0.0, 0.5) | result Thompson Sampling = 908 result Standard solution = 728
# N = 5000 d = 7 range = (0.0, 0.5) | result Thompson Sampling = 897 result Standard solution = 702
# N = 5000 d = 8 range = (0.0, 0.5) | result Thompson Sampling = 871 result Standard solution = 671
# N = 5000 d = 9 range = (0.0, 0.5) | result Thompson Sampling = 873 result Standard solution = 662
# N = 5000 d = 10 range = (0.0, 0.5) | result Thompson Sampling = 849 result Standard solution = 626
# N = 5000 d = 11 range = (0.0, 0.5) | result Thompson Sampling = 829 result Standard solution = 596
# N = 5000 d = 12 range = (0.0, 0.5) | result Thompson Sampling = 807 result Standard solution = 572
# N = 5000 d = 13 range = (0.0, 0.5) | result Thompson Sampling = 804 result Standard solution = 584
# N = 5000 d = 14 range = (0.0, 0.5) | result Thompson Sampling = 803 result Standard solution = 533
# N = 5000 d = 15 range = (0.0, 0.5) | result Thompson Sampling = 780 result Standard solution = 524
# N = 5000 d = 16 range = (0.0, 0.5) | result Thompson Sampling = 779 result Standard solution = 522
# N = 5000 d = 17 range = (0.0, 0.5) | result Thompson Sampling = 767 result Standard solution = 519
# N = 5000 d = 18 range = (0.0, 0.5) | result Thompson Sampling = 744 result Standard solution = 509
# N = 5000 d = 19 range = (0.0, 0.5) | result Thompson Sampling = 729 result Standard solution = 461
# N = 5000 d = 20 range = (0.0, 0.5) | result Thompson Sampling = 723 result Standard solution = 471
